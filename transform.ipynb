# %%
import pandas as pd
import import_ipynb

# %%
from extract import new_df

# %%
new_df.head()
# Out:
#     AREA  ST    STATE OCC_CODE                              OCC_TITLE  \
# 63     1  AL  Alabama  15-0000  Computer and Mathematical Occupations
# 64     1  AL  Alabama  15-1121              Computer Systems Analysts
# 65     1  AL  Alabama  15-1122          Information Security Analysts
# 66     1  AL  Alabama  15-1131                   Computer Programmers
# 67     1  AL  Alabama  15-1132      Software Developers, Applications
#
#    OCC_GROUP TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ...   H_MEDIAN H_PCT75 H_PCT90  \
# 63     major  39,760      2.3    20.680  0.69  ...      37.30   49.05   61.78
# 64  detailed   4,010      9.4     2.084  0.51  ...      37.89   46.97   56.72
# 65  detailed   1,100      7.8     0.573  0.78  ...      42.15   53.51   61.89
# 66  detailed   7,420      4.6     3.858  2.22  ...      40.49   51.08   65.95
# 67  detailed   5,540      5.5     2.883  0.48  ...      43.00   55.35   66.43
#
#    A_PCT10 A_PCT25 A_MEDIAN  A_PCT75  A_PCT90 ANNUAL HOURLY
# ...

# %%
final_df = new_df.rename(columns={"H_MEDIAN": "hourly_median", "A_MEDIAN": "annual_median", "OCC_CODE": "occupation_code", "OCC_TITLE": "occupation_title", "H_MEAN": "hourly_mean", "A_MEAN": "annual_mean", "TOT_EMP": "total_employment"})
final_df
# Out:
#        AREA  ST           STATE occupation_code  \
# 63        1  AL         Alabama         15-0000
# 64        1  AL         Alabama         15-1121
# 65        1  AL         Alabama         15-1122
# 66        1  AL         Alabama         15-1131
# 67        1  AL         Alabama         15-1132
# 68        1  AL         Alabama         15-1133
# 69        1  AL         Alabama         15-1134
# 70        1  AL         Alabama         15-1141
# 71        1  AL         Alabama         15-1142
# 72        1  AL         Alabama         15-1143
# 73        1  AL         Alabama         15-1151
# 74        1  AL         Alabama         15-1152
# 75        1  AL         Alabama         15-1199
# 76        1  AL         Alabama         15-2011
# 77        1  AL         Alabama         15-2031
# 78        1  AL         Alabama         15-2041
# 784       2  AK          Alaska         15-0000
# 785       2  AK          Alaska         15-1121
# ...

# %%
final_df.head()
# Out:
#     AREA  ST    STATE occupation_code                       occupation_title  \
# 63     1  AL  Alabama         15-0000  Computer and Mathematical Occupations
# 64     1  AL  Alabama         15-1121              Computer Systems Analysts
# 65     1  AL  Alabama         15-1122          Information Security Analysts
# 66     1  AL  Alabama         15-1131                   Computer Programmers
# 67     1  AL  Alabama         15-1132      Software Developers, Applications
#
#    OCC_GROUP total_employment EMP_PRSE JOBS_1000 LOC_Q  ...   hourly_median  \
# 63     major           39,760      2.3    20.680  0.69  ...           37.30
# 64  detailed            4,010      9.4     2.084  0.51  ...           37.89
# 65  detailed            1,100      7.8     0.573  0.78  ...           42.15
# 66  detailed            7,420      4.6     3.858  2.22  ...           40.49
# 67  detailed            5,540      5.5     2.883  0.48  ...           43.00
#
# ...

# %%
ca_df = final_df[final_df["ST"] == "CA"]
ca_df
# Out:
#       AREA  ST       STATE occupation_code  \
# 2802     6  CA  California         15-0000
# 2803     6  CA  California         15-1111
# 2804     6  CA  California         15-1121
# 2805     6  CA  California         15-1122
# 2806     6  CA  California         15-1131
# 2807     6  CA  California         15-1132
# 2808     6  CA  California         15-1133
# 2809     6  CA  California         15-1134
# 2810     6  CA  California         15-1141
# 2811     6  CA  California         15-1142
# 2812     6  CA  California         15-1143
# 2813     6  CA  California         15-1151
# 2814     6  CA  California         15-1152
# 2815     6  CA  California         15-1199
# 2816     6  CA  California         15-2011
# 2817     6  CA  California         15-2021
# 2818     6  CA  California         15-2031
# 2819     6  CA  California         15-2041
# 2820     6  CA  California         15-2090
#
#                                     occupation_title OCC_GROUP  \
# ...

# %%
occupations = ca_df[["occupation_code", "occupation_title"]].copy()
occupations.reset_index(drop=True, inplace=True)
occupations
# Out:
#    occupation_code                                occupation_title
# 0          15-0000           Computer and Mathematical Occupations
# 1          15-1111    Computer and Information Research Scientists
# 2          15-1121                       Computer Systems Analysts
# 3          15-1122                   Information Security Analysts
# 4          15-1131                            Computer Programmers
# 5          15-1132               Software Developers, Applications
# 6          15-1133           Software Developers, Systems Software
# 7          15-1134                                  Web Developers
# 8          15-1141                         Database Administrators
# 9          15-1142     Network and Computer Systems Administrators
# 10         15-1143                     Computer Network Architects
# 11         15-1151               Computer User Support Specialists
# 12         15-1152            Computer Network Support Specialists
# ...

# %%
yearly_stats = ca_df[["occupation_code", "hourly_median", "annual_median", "hourly_mean", "annual_mean", "total_employment"]].copy()
yearly_stats.reset_index(drop=True, inplace=True)
yearly_stats
# Out:
#    occupation_code hourly_median annual_median hourly_mean annual_mean  \
# 0          15-0000         48.31       100,480       50.66     105,380
# 1          15-1111         59.20       123,130       61.80     128,530
# 2          15-1121         47.08        97,940       49.45     102,860
# 3          15-1122         52.11       108,390       51.97     108,090
# 4          15-1131         45.01        93,620       46.28      96,270
# 5          15-1132         58.28       121,210       60.80     126,470
# 6          15-1133         59.71       124,190       61.17     127,230
# 7          15-1134         36.96        76,880       40.51      84,270
# 8          15-1141         45.92        95,500       45.98      95,630
# 9          15-1142         44.37        92,290       46.35      96,420
# 10         15-1143         60.19       125,190       61.91     128,770
# 11         15-1151         28.57        59,430       30.60      63,660
# ...
